# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrawanpandit/ImageProcessing-Lab-works/blob/main/Imageprocessing_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
image=cv2.imread('images.jpg');
from google.colab.patches import cv2_imshow
cv2_imshow(image)
print('original image');
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>
# original image

# %%
image1=cv2.imread('images.jpg',0);
cv2_imshow(image1)
print('grayscale image');
# Out:
# <PIL.Image.Image image mode=L size=251x201>
# grayscale image

# %%
from typing import dataclass_transform
import cv2
image=cv2.imread('images.jpg');
from google.colab.patches import cv2_imshow
cv2_imshow(image)
print('original image');
from numpy import asarray
data=asarray(image)
print(data)
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>
# original image
# [[[ 1  0 35]
#   [ 1  0 35]
#   [ 1  0 34]
#   ...
#   [ 8  2 33]
#   [12  6 37]
#   [19 12 45]]
#
#  [[ 1  0 35]
#   [ 1  0 35]
#   [ 2  1 35]
#   ...
#   [ 6  0 31]
#   [ 9  3 34]
#   [14  7 40]]
#
#  [[ 1  0 34]
#   [ 2  1 35]
#   [ 4  0 35]
#   ...
#   [ 5  0 30]
#   [ 7  1 32]
#   [10  3 36]]
#
#  ...
#
#  [[14  9 38]
#   [14  9 36]
#   [16  9 36]
#   ...
#   [48 47 43]
#   [48 47 43]
#   [50 47 43]]
#
#  [[ 8  3 32]
#   [ 8  3 30]
#   [11  4 31]
#   ...
#   [48 47 43]
#   [47 46 42]
#   [49 46 42]]
#
#  [[ 7  2 31]
#   [ 8  3 30]
#   [13  6 33]
#   ...
#   [38 36 35]
#   [36 34 33]
#   [33 31 30]]]

# %%
import cv2
import imutils
image=cv2.imread('images.jpg');
from google.colab.patches import cv2_imshow
cv2_imshow(image)
R1=imutils.rotate(image,90)
cv2_imshow(R1)
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>
# <PIL.Image.Image image mode=RGB size=251x201>

# %%
import cv2
image=cv2.imread('images.jpg');
from google.colab.patches import cv2_imshow

if image is None:
    print('Error: Could not load image. Please check if "download.jpg" exists and the path is correct.')
else:
    cv2_imshow(image)
    R,G,B,=cv2.split(image)
    C=255-R
    M=255-G
    Y=255-B
    cv2_imshow(R)
    print('Red component')
    cv2_imshow(M)
    print('Green component')

    cv2_imshow(Y)
    print('Blue component')
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>
# <PIL.Image.Image image mode=L size=251x201>
# Red component
# <PIL.Image.Image image mode=L size=251x201>
# Green component
# <PIL.Image.Image image mode=L size=251x201>
# Blue component

# %%
# !git clone https://github.com/Shrawanpandit/ImageProcessing-Lab-works.git
# Out:
# Cloning into 'ImageProcessing-Lab-works'...
# ...
